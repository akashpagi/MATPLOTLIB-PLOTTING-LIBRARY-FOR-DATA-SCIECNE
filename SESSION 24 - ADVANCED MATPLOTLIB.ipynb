# %% [markdown]
# ### SESSION 24 - ADVANCED MATPLOTLIB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Colored scatterplots**

# %%
iris = pd.read_csv('DATASETS/S24/iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 36    37            5.5           3.5            1.3           0.2
# 20    21            5.4           3.4            1.7           0.2
# 104  105            6.5           3.0            5.8           2.2
# 88    89            5.6           3.0            4.1           1.3
# 47    48            4.6           3.2            1.4           0.2
#
#              Species
# 36       Iris-setosa
# 20       Iris-setosa
# 104   Iris-virginica
# 88   Iris-versicolor
# 47       Iris-setosa

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,
                                           'Iris-versicolor':1,
                                          'Iris-virginica':2})
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# **plt.colorbar()**
# - The plt.colorbar() function in Matplotlib is used to add a colorbar to your plot.
# - A colorbar is a separate axis that displays the color mapping for the data in your plot.
# - It helps viewers understand the mapping between colors and data values.

# %%
# coorelation between SepalLengthCm and PetalLengthCm
plt.scatter(iris['SepalLengthCm'], 
            iris['PetalLengthCm'],
           c=iris['Species'],
           cmap='winter',
           alpha=0.4)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# **Changing Height and width of plot using plt.figure()**
# - To change the height and width of a plot in Matplotlib, you can use the figure function and specify the figsize parameter.
# - The figsize parameter takes a tuple of two values: the width and height of the figure in inches.

# %%
plt.figure(figsize=(8,4))
plt.scatter(iris['SepalLengthCm'], 
            iris['PetalLengthCm'],
           c=iris['Species'],
           cmap='winter',
           alpha=0.4)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# **Annotaions**

# %%
batters = pd.read_csv('DATASETS/S24/batter.csv')
batters.shape
sample_df = batters.head(100).sample(25, random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %% [markdown]
# **plt.text() function:**
#
# - The plt.text() function in Matplotlib is another way to add text annotations to a plot.
# - It allows you to place text at arbitrary positions on the plot.
# - **Syntax: plt.text(x, y, s, fontsize, horizontalalignment='center',verticalalignment='center', bbox)**
# - **Parameters:**
# - **x**: The x-coordinate of the text.
# - **y**: The y-coordinate of the text.
# - **s**: The text string.
# - **fontsize**: (Optional) Font size of the text.
# - **horizontalalignment**: (Optional) Horizontal alignment of the text. Default is 'center'.
# - **verticalalignment**: (Optional) Vertical alignment of the text. Default is 'center'.
# - **bbox**: (Optional) A dictionary specifying the properties of a bounding box around the text. This can include properties like facecolor, edgecolor, boxstyle etc.
# tc.
# *

# %%
#plt.figure(figsize=(14,10))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])
# annotation through for loop
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], 
             sample_df['strike_rate'].values[i], 
             sample_df['batter'].values[i])

# %% [markdown]
# **Horizontal and Vertical axis line**

# %% [markdown]
# **plt.axhlive():** plt.axhline() dds a horizontal line to a plot.
#
# **plt.axvline():** plt.axvline() adds a vertical line.
#
#
# - You specify the position of the line (either y for horizontal or x for vertical), and you can customize their appearance using parameters like color and linestyle.
# - These functions are part of the Matplotlib library in Python for creating data visualizations.

# %%
#  Foucus those batsman where strike rate is above 130
plt.scatter(sample_df['avg'], sample_df['strike_rate'])
plt.axhline(130, color='red')
plt.axhline(140, color='g')
plt.axvline(30, color='red')
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], 
             sample_df['strike_rate'].values[i], 
             sample_df['batter'].values[i])

# %% [markdown]
# **Subplots**
# - In Matplotlib, subplots allow you to create multiple plots within a single figure.
# - The plt.subplots() function is commonly used to create a grid of subplots.

# %%
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(batters['avg'],batters['strike_rate'])

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# **plt.subplots()**
# - this function produce figure and axes object for plot.
# - using figure and axes object we can plot subplots

# %%
# using fig, ax object ploting 
fig, ax = plt.subplots()
ax.scatter(batters['avg'],batters['strike_rate'])

# %%
fig, ax = plt.subplots()
ax.plot(batters['avg'],batters['strike_rate'])
# adding title
ax.set_title('Subplot Example')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike rate')
# Out:
# Text(0, 0.5, 'Strike rate')

# %%
fig, ax = plt.subplots()
ax.scatter(batters['avg'],batters['strike_rate'])
# adding title
ax.set_title('Subplot Example')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike rate')
# Out:
# Text(0, 0.5, 'Strike rate')

# %%
fig, ax = plt.subplots()
ax.scatter(batters['avg'],batters['strike_rate'], marker='+',color='r')
# adding title
ax.set_title('Subplot Example')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike rate')
# Out:
# Text(0, 0.5, 'Strike rate')

# %% [markdown]
# **Multiple subplots at same time**

# %%
fig, ax = plt.subplots(nrows=2,ncols=1, sharex=True)
ax[0].scatter(batter['avg'],batter['strike_rate'], color='g',marker='+')
ax[0].set_title('Avg Vs Strike Rate')
#ax[0].set_xlabel('Avg')
ax[0].set_ylabel('Strike Rate')

ax[1].scatter(batter['avg'],batter['runs'])
ax[1].set_title('Avg Vs Runs')
ax[1].set_xlabel('Avg')
ax[1].set_ylabel('Runs')
plt.show()
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 fig, ax = plt.subplots(nrows=2,ncols=1, sharex=True)
# ----> 2 ax[0].scatter(batter['avg'],batter['strike_rate'], color='g',marker='+')
#       3 ax[0].set_title('Avg Vs Strike Rate')
#       4 #ax[0].set_xlabel('Avg')
#
# NameError: name 'batter' is not defined

# %%
# multiple plots
fig, ax = plt.subplots(nrows=2,ncols=2)
ax[0,0].scatter(batter['avg'],batter['strike_rate'], color='g',marker='+')
ax[0,1].scatter(batter['avg'],batter['runs'],color='r')
ax[1,0].hist(batter['avg'])
ax[1,1].hist(batter['runs'])
plt.show()

# %% [markdown]
# **3D Scatter Plots**

# %%
batters

# %%
#fig = plt.figure(figsize=(15,15))
ax = plt.subplot(projection='3d')
ax.scatter3D(batters['runs'], batters['avg'],batters['strike_rate'])
ax.set_title('IPL batsman analysis')
ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('Strike Rate')

# %% [markdown]
# **3D Surface Plots**

# %%
fig = plt.figure(figsize=(12,8))
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx, yy = np.meshgrid(x,y)
z = xx**2 + yy**2
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %%
# Contour Plot
fig = plt.figure(figsize=(10,7))
ax = plt.subplot()
p = plt.contour(xx, yy, z, cmap='viridis')
fig.colorbar(p)
plt.show()

# %%
# contourf plot (filled)
fig = plt.figure(figsize=(10,7))
ax = plt.subplot()
p = plt.contourf(xx, yy, z, cmap='viridis')
fig.colorbar(p)
plt.show()

# %%
# Another example
fig = plt.figure(figsize=(10,7))
z = np.sin(xx) + np.cos(yy)
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)
plt.show()

# %% [markdown]
# **Contour Plots (2D)**
# - Contour plots in machine learning are used to visualize relationships between two continuous variables and understand how a third variable (like a cost function or performance metric) changes across the feature space
#
# -  They are commonly employed in scenarios such as visualizing cost functions during optimization, tuning hyperparameters, exploring feature interactions, visualizing decision boundaries in SVM, and understanding neural network weight landscapes
#
# -  Contour plots provide an intuitive way to analyze and make decisions about model parameters or features in a 2D space.

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.subplot()
p = plt.contour(xx, yy, z, cmap='viridis')
fig.colorbar(p)
plt.show()

# %%
# contourf plot (filled)
fig = plt.figure(figsize=(10,7))
ax = plt.subplot()
p = plt.contourf(xx, yy, z, cmap='viridis')
fig.colorbar(p)
plt.show()

# %% [markdown]
# **HeatMap:**
# - Displaying data that relies on two independent variables can be effectively visualized using a color-coded image plot, commonly known as a heatmap.

# %%
# Ex. For each over, calculate the occurrence of a six for every ball bowled in all seasons.
delivery = pd.read_csv('DATASETS/S24/IPL_Ball_by_Ball_2008_2022.csv')
delivery.head()

# %%
temp_df = delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run'] == 6)]
temp_df.head()

# %%
grid = temp_df.pivot_table(index='overs', columns='ballnumber',
                           values='batsman_run',aggfunc='count')
p = plt.imshow(grid)
plt.yticks(delivery['overs'].unique(), list(range(1,21)))
plt.xticks(np.arange(0,6)), list(range(1,7))
plt.colorbar()
plt.show()

# %% [markdown]
# **Pandas plot() function:**
#
# - The plot() function in pandas is a versatile tool for creating various types of plots directly from DataFrame or Series data.
# - Using pandas plot() function we can plotting matplotlib library plots but not more customizable like matplotlib plotting library .

# %% [markdown]
# **on the series data**

# %%
# on the series data
s = pd.Series([1,2,3,4,5,6,7])
s.plot(kind='pie')

# %% [markdown]
# **on dataframe**

# %%
# dataframe
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# scatter plot -> labels > markers > color > cmap
tips.plot(kind='scatter', x='total_bill', 
          y='tip', title='Cost Analysis',c='sex',
         cmap='viridis', marker='+')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **2d plot()**

# %%
# 2d plot
# dataset = 'https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv'

stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %% [markdown]
# **line plot**

# %%
# on series
stocks['MSFT'].plot()
# Out:
# <Axes: >

# %%
# line plot on dataframe
stocks.plot(kind='line',x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# line plot on dataframe
stocks[['Date','FB','AAPL']].plot(kind='line',x='Date')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Bar chart**

# %%
# bar chart -> single -> horizontal -> multiple
# using tips
import seaborn as sns
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
temp = pd.read_csv('DATASETS/S24/batsman_season_record.csv')
temp.head()
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
# bar chart
tips.groupby('sex')['total_bill'].mean().plot(kind='bar')
# Out:
# C:\Users\Akash Pagi\AppData\Local\Temp\ipykernel_3884\3187018826.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['total_bill'].mean().plot(kind='bar')
# <Axes: xlabel='sex'>

# %%
# side bar chart
temp.plot(kind='bar')
# Out:
# <Axes: >

# %%
# stacked bar chart
temp.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
# histogram 
temp.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# pie -> single and multiple
df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,90,35,45,12,10],
        'match2':[0,1,123,130,34,45],
        'match3':[50,24,145,45,10,90]
    }
)
df.head()
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120       0      50
# 1   Rohit      90       1      24
# 2   Kohli      35     123     145
# 3     SKY      45     130      45
# 4  Pandya      12      34      10

# %%
df['match1'].plot(kind='pie', 
                  labels=df['batsman'].values, 
                  autopct='%0.1f%%',
                 )
# Out:
# <Axes: ylabel='match1'>

# %%
# Multiple pie chart
df[['match1','match2','match3']].plot(kind='pie',
                                      subplots=True,
                                     figsize=(15,8))
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)

# %%
# multiple separate graphs together
# using stocks

stocks.plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# on multiindex dataframes
# using tips dataframe

# %%
tips.pivot_table(index=['day','time'],
                 columns=['sex','smoker'],
                 values='total_bill',
                 aggfunc='mean').plot(kind='pie',
                 subplots=True,                                                                
                figsize=(20,10))
plt.show()
